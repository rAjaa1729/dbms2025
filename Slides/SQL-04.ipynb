# %% [markdown]
# # SQL-04

# %% [markdown]
# ## Prepare the environment
#
# ---

# %%
pip install ipython-sql psycopg2-binary
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.10/site-packages (2.9.10)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/site-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython-sql) (8.31.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.10/site-packages (from ipython-sql) (2.0.37)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: decorator in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/site-packages (from ipython->ipython-sql) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from stack_data->ipython->ipython-sql) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/sumansalvi/Library/Python/3.10/lib/python/site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## Data Definition Lanaguage (DDL)
# The SQL data-definition language (DDL) allows specification of:
# * Schema for each relation
# * Data type of values associated with each attribute
# * Integrity constraints
# * Creating, deleting, and updating tables
# * Views
# * Constraints

# %% [markdown]
# First create a new database from command line
#
# postgres# `create database cricdb;`

# %%
# %sql postgresql://postgres:dbms2025@localhost:5432/cricdb

# %% [markdown]
# ---
# ## Data types in SQL
# ---
#
# ### Basic Types
# * **char($n$) or character($n$)**. Fixed length character string, with user specified length $n$.
# * **varchar($n$) or varying character($n$)**. Variable length character strings, with user-specified maximum length $n$.
# * **int or integer**. Integer (a finite subset of the integers that is machine-dependent)
# * **smallint**. Small integer (a machine-dependent subset of the integer domain type).
# * **numeric($m,n$)** $m \implies$ number of digits, and $n \leq m \implies$ number of digits that are to the right of the decimal point (ex. numeric(3,1) allows 44.5 to be stored exactly, but not 0.32 or 444.5).
# * **float($n$)**. floating point number of user-specified $n$ digits
# * real, double precision
#
# Note: Each type may include a **null** value
#
#
# ### Other data types
# * date
# * time
# * timestamp
# * clob
# * blob
# * user-defined types
#
# ---

# %% [markdown]
# ## Creating/Updating/Deletions
# ```
# create table table_name (
#     attribute_1 data_type_1,
#     attribute_2 data_type_2,
#     ...
#     attribute_n data_type_n
# )
# ```

# %%
# %sql drop table if exists player
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %%
# %%sql create table player (
#     player_id integer,
#     first_name varchar(25),
#     last_name varchar(25),
#     dob date,
#     team_id integer
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %%
# %sql select * from pg_catalog.pg_tables limit 10;
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %%sql create table team (
#     team_id integer,
#     team_name varchar(50),
#     team_owner varchar(50)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# (psycopg2.errors.DuplicateTable) relation "team" already exists
#
# [SQL: create table team (
#     team_id integer,
#     team_name varchar(50),
#     team_owner varchar(50)
# )]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# Lets insert some values into the two relations

# %%
# %%sql insert into player values
#     (1, 'Hardik', 'Pandya', '1993-10-11', 101),
#     (2, 'MS', 'Dhoni', '1981-07-07', 102),
#     (3, 'Rohit', 'Sharma', '1987-04-30', 101),
#     (4, 'Ruturaj', 'Gaikwad', '1997-01-31', 102);
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 4 rows affected.
# []

# %%
# %%sql insert into team values
#     (101, 'Mumbai Indians', 'Reliance Industry Ltd'),
#     (102, 'Chennai Super Kings', 'India Cements Ltd'),
#     (103, 'Delhi Capitals', 'JSW Sports')
#     ;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 3 rows affected.
# []

# %%
# %sql select * from player
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 4 rows affected.
# [(1, 'Hardik', 'Pandya', datetime.date(1993, 10, 11), 101),
#  (2, 'MS', 'Dhoni', datetime.date(1981, 7, 7), 102),
#  (3, 'Rohit', 'Sharma', datetime.date(1987, 4, 30), 101),
#  (4, 'Ruturaj', 'Gaikwad', datetime.date(1997, 1, 31), 102)]

# %% [markdown]
# ### Deletions
#
# ```
# delete from table_name
#     where condition;
# ```

# %% [markdown]
# Detele all players from team `102`

# %%
# %%sql delete from player
# where team_id = 102;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 2 rows affected.
# []

# %%
# %sql select * from team
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 3 rows affected.
# [(101, 'Mumbai Indians', 'Reliance Industry Ltd'),
#  (102, 'Chennai Super Kings', 'India Cements Ltd'),
#  (103, 'Delhi Capitals', 'JSW Sports')]

# %%
# %%sql delete from player
# where team_id IN (
#     select team_id from team where team_name = 'Delhi Capitals'
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 0 rows affected.
# []

# %% [markdown]
# ### Updating tables
# * Change value in a tuple

# %%
# %sql select * from player;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 2 rows affected.
# [(1, 'Hardik', 'Pandya', datetime.date(1993, 10, 11), 101),
#  (3, 'Rohit', 'Sharma', datetime.date(1987, 4, 30), 101)]

# %%
# %%sql update player
# set team_id = 102
# where player.first_name = 'Hardik' and player.last_name = 'Pandya';
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 1 rows affected.
# []

# %%
# %sql select * from player;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 2 rows affected.
# [(3, 'Rohit', 'Sharma', datetime.date(1987, 4, 30), 101),
#  (1, 'Hardik', 'Pandya', datetime.date(1993, 10, 11), 102)]

# %% [markdown]
# ### Altering tables
#
# ```
# alter table table_name add attribute data_type
# alter table table_name drop attribute
# delete from table_name
# drop table table_name
# ```

# %% [markdown]
# Add a new attribute `position` to the relation `player`

# %%
# %sql alter table player add position smallint;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %%
# %sql select * from player;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 2 rows affected.
# [(3, 'Rohit', 'Sharma', datetime.date(1987, 4, 30), 101, None),
#  (1, 'Hardik', 'Pandya', datetime.date(1993, 10, 11), 102, None)]

# %% [markdown]
# Q: Update the `position` values in the `player` relation.

# %%
# %sql update player set position = 4 where player_id = 1;
# %sql update player set position = 1 where player_id = 3;
# %sql update player set position = 3 where player_id = 2;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 1 rows affected.
#  * postgresql://postgres:***@localhost:5432/cricdb
# 1 rows affected.
#  * postgresql://postgres:***@localhost:5432/cricdb
# 0 rows affected.
# []

# %%
# %sql select * from player
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 2 rows affected.
# [(1, 'Hardik', 'Pandya', datetime.date(1993, 10, 11), 102, 4),
#  (3, 'Rohit', 'Sharma', datetime.date(1987, 4, 30), 101, 1)]

# %%
# %sql alter table player drop position;

# %% [markdown]
# ## Views
#
# * Sometimes, we may want to hide the entire logical model from certain users.
#
# * A view provides a mechanism to hide certain data from the view of certain users
#
# * Any relation that is not of the conceptual model but is made visible to a user as a "virtual relation" is called a view
#
# * Two type of views
#     1. Virtual views
#     2. Materialized views
#
# * To create a view
#
#     **create view** view_name **as** \<query_expression\>

# %% [markdown]
# Create a view `top_mi_csk_players` (top order batters from 'Mumbai Indians' and 'Chennai Super Kings')

# %%
# %%sql create view top_mi_csk_players as
# select first_name, last_name, team_name
# from player join team on player.team_id = team.team_id
# where team_name = 'Mumbai Indians' or team_name = 'Chennai Super Kings'
# and position < 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %%
# %sql select * from top_mi_csk_players;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 2 rows affected.
# [('Hardik', 'Pandya', 'Chennai Super Kings'),
#  ('Rohit', 'Sharma', 'Mumbai Indians')]

# %% [markdown]
# To create a materialized view,
# ``` create materialized view as <query>```

# %% [markdown]
# * Q. What is the difference between a view and the CTE defined in `WITH` clause?

# %% [markdown]
# ---
# ## Integrity Constraints
# * Crucial for data consistency
# * Usually a part of schema design and is specified with `create table` statement

# %%
# %sql insert into player values (1, 'Hardik', 'Pandya', null, null);
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# (psycopg2.errors.NotNullViolation) null value in column "dob" of relation "player" violates not-null constraint
# DETAIL:  Failing row contains (1, Hardik, Pandya, null, null).
#
# [SQL: insert into player values (1, 'Hardik' , 'Pandya' , null, null);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %sql select * from player;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# 0 rows affected.
# []

# %%
# %sql drop view top_mi_csk_players;
# %sql drop table player;
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# (psycopg2.errors.UndefinedTable) view "top_mi_csk_players" does not exist
#
# [SQL: drop view top_mi_csk_players;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %% [markdown]
# ### Common constraints
# * not null
# * primary key
# * unique
# * check(*condition*)
# * referential-integrity

# %%
# %%sql create table player (
#     player_id integer not null,
#     first_name varchar(25) not null,
#     last_name varchar(25) not null,
#     dob date not null,
#     team_id integer,
#     primary key (player_id),
#     unique(player_id, dob),
#     check (dob > '1990-01-31'),
#     foreign key (team_id) references team (team_id)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %%
# %sql drop table player
# %sql drop table if exists team
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# (psycopg2.errors.UndefinedTable) table "player" does not exist
#
# [SQL: drop table player]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %%
# %%sql create table team (
#     team_id integer,
#     team_name varchar(50) not null,
#     team_owner varchar(50) not null,
#     primary key (team_id)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/cricdb
# Done.
# []

# %% [markdown]
# ---

# %% [markdown]
# ## Exercises

# %% [markdown]
# * Q: Create or update the database `cricdb`, by adding more relations. Take the ERD discussed in class as an example.
#
# * Q. Try different DDL statements
#
# * Q. Try update statements on view. What will happen when you update the view `top_mi_csk_players` as ('5', 'Ravindra', 'Jadeja')? Will it update the "base" tables?
#
# * Q. Try updating schema of an existing relation by adding a constraint? what happens if the existing values don't satisfy the constraints?
#
# * Q. Write some insert statements to violate different types of constraints.
#
# * Q. What happens when you delete a table, which has been used in query definition of a view?
#
# * Q. What happens when you a delete a tuple from `player` relation with foreign key constraint?
